# %%
import pandas as pd

url1 = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv'
url2 = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv'
url3 = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Recovered.csv'
infected = pd.read_csv(url1,index_col=0)
death = pd.read_csv(url2,index_col=0)
recovered =pd.read_csv(url3,index_col=0)

infected.head()
# Out:
#                 Country/Region       Lat      Long  1/22/20  1/23/20  1/24/20  \
# Province/State
# Anhui           Mainland China  31.82571  117.2264        1        9       15
# Beijing         Mainland China  40.18238  116.4142       14       22       36
# Chongqing       Mainland China  30.05718  107.8740        6        9       27
# Fujian          Mainland China  26.07783  117.9895        1        5       10
# Gansu           Mainland China  36.06110  103.8343        0        2        2
#
#                 1/25/20  1/26/20  1/27/20  1/28/20  ...  2/16/20  2/17/20  \
# Province/State                                      ...
# Anhui                39       60       70      106  ...      962      973
# Beijing              41       68       80       91  ...      380      381
# Chongqing            57       75      110      132  ...      551      553
# Fujian               18       35       59       80  ...      287      290
# ...

# %%
sum_infected = infected.sum(axis = 0,skipna = True)
sum_death = death.sum(axis = 0, skipna = True)
sum_recovered = recovered.sum(axis = 0, skipna = True)


#sum_infected.drop("Province/State")
sum_infected
# Out:
# Country/Region    Mainland ChinaMainland ChinaMainland ChinaMain...
# Lat                                                         2935.27
# Long                                                        4389.93
# 1/22/20                                                         555
# 1/23/20                                                         653
# 1/24/20                                                         941
# 1/25/20                                                        1434
# 1/26/20                                                        2118
# 1/27/20                                                        2927
# 1/28/20                                                        5578
# 1/29/20                                                        6166
# 1/30/20                                                        8234
# 1/31/20                                                        9927
# 2/1/20                                                        12038
# ...

# %%
sum_infected=sum_infected.drop("Lat")
sum_infected=sum_infected.drop("Long")
sum_infected=sum_infected.drop("Country/Region")

sum_death=sum_death.drop("Lat")
sum_death=sum_death.drop("Long")
sum_death=sum_death.drop("Country/Region")


sum_recovered=sum_recovered.drop("Lat")
sum_recovered=sum_recovered.drop("Long")
sum_recovered=sum_recovered.drop("Country/Region")

# %%
df = pd.DataFrame([sum_infected, sum_death, sum_recovered])
df
# Out:
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  \
# 0      555      653      941     1434     2118     2927     5578     6166
# 1       17       18       26       42       56       82      131      133
# 2       28       30       36       39       52       61      107      126
#
#    1/30/20  1/31/20  ...  2/16/20  2/17/20  2/18/20  2/19/20  2/20/20  \
# 0     8234     9927  ...    71226    73260    75138    75641    76199
# 1      171      213  ...     1770     1868     2007     2122     2247
# 2      143      222  ...    10865    12583    14352    16121    18177
#
#    2/21/20  2/22/20  2/23/20  2/24/20  2/25/20
# 0    76843    78599    78985    79570    80415
# 1     2251     2458     2469     2629     2708
# 2    18890    22886    23394    25227    27905
#
# [3 rows x 35 columns]

# %%
df = df.T

# %%
df
# Out:
#              0     1      2
# 1/22/20    555    17     28
# 1/23/20    653    18     30
# 1/24/20    941    26     36
# 1/25/20   1434    42     39
# 1/26/20   2118    56     52
# 1/27/20   2927    82     61
# 1/28/20   5578   131    107
# 1/29/20   6166   133    126
# 1/30/20   8234   171    143
# 1/31/20   9927   213    222
# 2/1/20   12038   259    284
# 2/2/20   16787   362    472
# 2/3/20   19881   426    623
# 2/4/20   23892   492    852
# 2/5/20   27636   564   1124
# 2/6/20   30818   634   1487
# 2/7/20   34392   719   2011
# 2/8/20   37121   806   2616
# 2/9/20   40151   906   3244
# 2/10/20  42763  1013   3946
# 2/11/20  44803  1113   4683
# 2/12/20  45222  1118   5150
# 2/13/20  60370  1371   6295
# 2/14/20  66887  1523   8058
# 2/15/20  69032  1666   9395
# 2/16/20  71226  1770  10865
# 2/17/20  73260  1868  12583
# 2/18/20  75138  2007  14352
# 2/19/20  75641  2122  16121
# 2/20/20  76199  2247  18177
# 2/21/20  76843  2251  18890
# 2/22/20  78599  2458  22886
# ...

# %%
df.plot

# %%
plt.figure(figsize=(15,5))

plt.plot(df)
